# %% [markdown]
# # PolyLab Google notebook job 90cb5e87-e3a5-4732-9419-04c9ba29558b
#
# Notebook-native educational workloads are routed to a Google notebook runtime.

# %%
import os, subprocess
os.environ["POLYLAB_CLOUD_JOB_ID"] = "90cb5e87-e3a5-4732-9419-04c9ba29558b"
subprocess.run("python3 notebooks/lesson.py", shell=True, check=True)
